# %%
### 開根號*10 誰最賺

import numpy as np
import matplotlib.pyplot as plt

x_data = np.arange(0, 101, 1)
y_data = np.sqrt(x_data) * 10

# diff
y_diff = y_data - x_data

plt.plot(x_data, y_data)
plt.plot(x_data, y_diff)
plt.vlines(max(y_diff), 0, 100, colors="red")

# %%
max(y_diff)
# Out:
# 25.0
